# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from pprint import pprint


# Import API key
from api_keys import yelp_api_key
from yelpapi import YelpAPI
yelp_api = YelpAPI(yelp_api_key)

# %%
response = yelp_api.search_query(term='MCDONALDS', location='New Jersey')
pprint(response)
# Out:
# {'businesses': [{'alias': 'mcdonalds-newark-6',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.735973,
#                                  'longitude': -74.171629},
#                  'display_phone': '(973) 624-8434',
#                  'distance': 78.27601915905721,
#                  'id': 'BDuRXATWGcMv4OE8jKkJ-Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rRkZAR11Oa8uBLcexuGmog/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '772 Broad St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['772 Broad St',
#                                                   'Newark, NJ 07102'],
#                               'state': 'NJ',
#                               'zip_code': '07102'},
#                  'name': "McDonald's",
#                  'phone': '+19736248434',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 12,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-6?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-10',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.734896,
#                                  'longitude': -74.164231},
#                  'display_phone': '(973) 624-5034',
#                  'distance': 638.4114893623885,
#                  'id': 'Xh932sOcE_68PIc8ekk3tA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/69W10zMT-PMXCiI7janyDg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '7944 Penn Sta',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['7944 Penn Sta',
#                                                   'Newark, NJ 07102'],
#                               'state': 'NJ',
#                               'zip_code': '07102'},
#                  'name': "McDonald's",
#                  'phone': '+19736245034',
#                  'price': '$',
#                  'rating': 2.5,
#                  'review_count': 28,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-10?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-14',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.72659, 'longitude': -74.17302},
#                  'display_phone': '(973) 643-0810',
#                  'distance': 965.1746973126253,
#                  'id': '8ndVdwDsdyq0DUrLmiqPEg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-msoUeToclMmoFl8DsjRqw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '561 Mccarter Hwy',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['561 Mccarter Hwy',
#                                                   'Newark, NJ 07102'],
#                               'state': 'NJ',
#                               'zip_code': '07102'},
#                  'name': "McDonald's",
#                  'phone': '+19736430810',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 10,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-14?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-38',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.73561, 'longitude': -74.18611},
#                  'display_phone': '(973) 565-9438',
#                  'distance': 1214.699671683666,
#                  'id': 'qgCU4qcv7d3-NMeWlIF1oQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jRONmp2arfCB8vf_VlqX7w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '188 Springfield Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['188 Springfield Ave',
#                                                   'Newark, NJ 07103'],
#                               'state': 'NJ',
#                               'zip_code': '07103'},
#                  'name': "McDonald's",
#                  'phone': '+19735659438',
#                  'price': '$',
#                  'rating': 3.0,
#                  'review_count': 4,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-38?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-35',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'burgers', 'title': 'Burgers'}],
#                  'coordinates': {'latitude': 40.72956, 'longitude': -74.158821},
#                  'display_phone': '(973) 465-8684',
#                  'distance': 1264.4542832810243,
#                  'id': '78vwBSXsWJDHRg2zdAw6pw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TP11DZVe2PUscEyXISf2hw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '148 Ferry St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['148 Ferry St',
#                                                   'Newark, NJ 07105'],
#                               'state': 'NJ',
#                               'zip_code': '07105'},
#                  'name': "McDonald's",
#                  'phone': '+19734658684',
#                  'price': '$',
#                  'rating': 2.5,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-35?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-13',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.7255788423548,
#                                  'longitude': -74.1823495352924},
#                  'display_phone': '(973) 824-4463',
#                  'distance': 1398.2565884467897,
#                  'id': 'J2sfRdn93mK-ckWSpdnPiQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HvF9yrKdw1eRDCGXwEA4Jg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '101-115 Clinton Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['101-115 Clinton Ave',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': "McDonald's",
#                  'phone': '+19738244463',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-13?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-19',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.7453525455329,
#                                  'longitude': -74.190336093254},
#                  'display_phone': '(973) 642-0064',
#                  'distance': 1922.3931988278755,
#                  'id': 'Z5tnsVEbqTn4kqEorYBG3A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xjSosK7r7-lFrjXBXYRTEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '334 W Market St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['334 W Market St',
#                                                   'Newark, NJ 07102'],
#                               'state': 'NJ',
#                               'zip_code': '07102'},
#                  'name': "McDonald's",
#                  'phone': '+19736420064',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 11,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-19?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-irvington-2',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'burgers', 'title': 'Burgers'}],
#                  'coordinates': {'latitude': 40.7285413206706,
#                                  'longitude': -74.2179708264302},
#                  'display_phone': '(973) 373-9194',
#                  'distance': 3962.6012753873997,
#                  'id': 'XFDRfT52EV9h3ogVgvF7zg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fuf3UnJaRDbe5BryL2_Z6g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '783 Springfield Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Irvington',
#                               'country': 'US',
#                               'display_address': ['783 Springfield Ave',
#                                                   'Irvington, NJ 07111'],
#                               'state': 'NJ',
#                               'zip_code': '07111'},
#                  'name': "McDonald's",
#                  'phone': '+19733739194',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-irvington-2?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-2',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.771912,
#                                  'longitude': -74.1615262056052},
#                  'display_phone': '(973) 482-3002',
#                  'distance': 4164.062693387365,
#                  'id': 'gXwmEwpLQJNR_rMCT4z6xA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f7WrbwJU1qPhwnjjAo69Jg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '621 Broadway',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['621 Broadway',
#                                                   'Newark, NJ 07104'],
#                               'state': 'NJ',
#                               'zip_code': '07104'},
#                  'name': "McDonald's",
#                  'phone': '+19734823002',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 9,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-2?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-east-orange',
#                  'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.7558415691415,
#                                  'longitude': -74.2170402318771},
#                  'display_phone': '(973) 676-3170',
#                  'distance': 4445.016056635122,
#                  'id': 'JJ6oxIJsm6w0bf2IQgh2zg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6aZw_HwwBt0VBoY5ir6Jlg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '375 Central Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'East Orange',
#                               'country': 'US',
#                               'display_address': ['375 Central Ave',
#                                                   'East Orange, NJ 07018'],
#                               'state': 'NJ',
#                               'zip_code': '07018'},
#                  'name': "McDonald's",
#                  'phone': '+19736763170',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 9,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-east-orange?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-26',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.7381868793448,
#                                  'longitude': -74.2251522839069},
#                  'display_phone': '(973) 371-2876',
#                  'distance': 4507.505573262457,
#                  'id': 'Q2m6-zZTDRD15YsAwqJXLA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RBfusFMeeAptMoSzEBMpYA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '915 18th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['915 18th Ave',
#                                                   'Newark, NJ 07106'],
#                               'state': 'NJ',
#                               'zip_code': '07106'},
#                  'name': "McDonald's",
#                  'phone': '+19733712876',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-26?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-belleville-5',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.7825013315129,
#                                  'longitude': -74.1828981041908},
#                  'display_phone': '(973) 751-5218',
#                  'distance': 5333.469541698666,
#                  'id': '5bA5PkO2zk_W_ocvdEJAjg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/is4GyOALpQHInxMUfi2xvA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '173 Franklin St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Belleville',
#                               'country': 'US',
#                               'display_address': ['173 Franklin St',
#                                                   'Belleville, NJ 07109'],
#                               'state': 'NJ',
#                               'zip_code': '07109'},
#                  'name': "McDonald's",
#                  'phone': '+19737515218',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 16,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-belleville-5?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-newark-28',
#                  'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'hotdogs', 'title': 'Fast Food'}],
#                  'coordinates': {'latitude': 40.690105,
#                                  'longitude': -74.202313},
#                  'display_phone': '(973) 643-9657',
#                  'distance': 5643.625066551398,
#                  'id': 'Ivc9Jo6uANCmj43iYbSGKQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Bju1Xf1kFb6gkCEfZLBe4A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '872-934 Frelinghuysen',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': ['872-934 Frelinghuysen',
#                                                   'Newark, NJ 07114'],
#                               'state': 'NJ',
#                               'zip_code': '07114'},
#                  'name': "McDonald's",
#                  'phone': '+19736439657',
#                  'price': '$',
#                  'rating': 2.5,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-newark-28?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-orange-19',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'burgers', 'title': 'Burgers'}],
#                  'coordinates': {'latitude': 40.7704394903878,
#                                  'longitude': -74.224867181083},
#                  'display_phone': '(973) 678-3680',
#                  'distance': 5939.086111237655,
#                  'id': 'McyhIo_Hhw4NLZtvjrL9hQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tcC1OCR9PCB1K3BS1iWkmw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '145-147 Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Orange',
#                               'country': 'US',
#                               'display_address': ['145-147 Main St',
#                                                   'Orange, NJ 07050'],
#                               'state': 'NJ',
#                               'zip_code': '07050'},
#                  'name': "McDonald's",
#                  'phone': '+19736783680',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-orange-19?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-hillside-2',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'},
#                                 {'alias': 'burgers', 'title': 'Burgers'}],
#                  'coordinates': {'latitude': 40.6989848062268,
#                                  'longitude': -74.2361761629581},
#                  'display_phone': '(908) 686-4171',
#                  'distance': 6762.589729697074,
#                  'id': '6LGDzuSMhN-L1ZSGT1OC1Q',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4g9vVWBHbhXThmvIJa0CVQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '395 Long Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Hillside',
#                               'country': 'US',
#                               'display_address': ['395 Long Ave',
#                                                   'Hillside, NJ 07205'],
#                               'state': 'NJ',
#                               'zip_code': '07205'},
#                  'name': "McDonald's",
#                  'phone': '+19086864171',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-hillside-2?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-elizabeth',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.675609,
#                                  'longitude': -74.191902},
#                  'display_phone': '(908) 469-8684',
#                  'distance': 6848.223885504702,
#                  'id': 'R1i864TDy2BWQfi4BgAfuw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1GwtpE3JlnYjHWVJS6cvsg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '819 North Ave E',
#                               'address2': 'Ste 835',
#                               'address3': '',
#                               'city': 'Elizabeth',
#                               'country': 'US',
#                               'display_address': ['819 North Ave E',
#                                                   'Ste 835',
#                                                   'Elizabeth, NJ 07201'],
#                               'state': 'NJ',
#                               'zip_code': '07201'},
#                  'name': "McDonald's",
#                  'phone': '+19084698684',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-elizabeth?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-bayonne',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.6942496949283,
#                                  'longitude': -74.1028415449364},
#                  'display_phone': '(201) 339-3174',
#                  'distance': 7388.163265048994,
#                  'id': '26Y1wswjXx1Q1QuANbz-gA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/B06DNDvHnfee-Gy71edRRQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '157 W 63rd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Bayonne',
#                               'country': 'US',
#                               'display_address': ['157 W 63rd St',
#                                                   'Bayonne, NJ 07002'],
#                               'state': 'NJ',
#                               'zip_code': '07002'},
#                  'name': "McDonald's",
#                  'phone': '+12013393174',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 16,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-bayonne?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-jersey-city-9',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.7221107,
#                                  'longitude': -74.084831},
#                  'display_phone': '(201) 333-6889',
#                  'distance': 7472.510517949269,
#                  'id': '0nfUrtjX4C_e1NDB-dBN8w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-rDMi-znnSsy-2wIEwRcJg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '891 Cummunipaw Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Jersey City',
#                               'country': 'US',
#                               'display_address': ['891 Cummunipaw Ave',
#                                                   'Jersey City, NJ 07304'],
#                               'state': 'NJ',
#                               'zip_code': '07304'},
#                  'name': "McDonald's",
#                  'phone': '+12013336889',
#                  'price': '$',
#                  'rating': 1.5,
#                  'review_count': 33,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-jersey-city-9?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-belleville-4',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.8033478339938,
#                                  'longitude': -74.1463275253773},
#                  'display_phone': '(973) 751-6700',
#                  'distance': 7866.708775814931,
#                  'id': 'VKJfmKrXc4meUemQDUmsxQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qUciz7qcybM1szoRpcnC8Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '663 Washington Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Belleville',
#                               'country': 'US',
#                               'display_address': ['663 Washington Ave',
#                                                   'Belleville, NJ 07109'],
#                               'state': 'NJ',
#                               'zip_code': '07109'},
#                  'name': "McDonald's",
#                  'phone': '+19737516700',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 37,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-belleville-4?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'},
#                 {'alias': 'mcdonalds-union-7',
#                  'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 40.6984784636688,
#                                  'longitude': -74.251856},
#                  'display_phone': '(908) 964-4500',
#                  'distance': 7891.666413352593,
#                  'id': '4KJ3binOkA5Wc4hHEuESxg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RmQZoWYomGi7LAHqmvtfSg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': 'Vauxhall Service Plz',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Union',
#                               'country': 'US',
#                               'display_address': ['Vauxhall Service Plz',
#                                                   'Union, NJ 07083'],
#                               'state': 'NJ',
#                               'zip_code': '07083'},
#                  'name': "McDonald's",
#                  'phone': '+19089644500',
#                  'price': '$',
#                  'rating': 1.0,
#                  'review_count': 10,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mcdonalds-union-7?adjust_creative=wSF0s5qiC_KNKvEnvXdWbg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=wSF0s5qiC_KNKvEnvXdWbg'}],
#  'region': {'center': {'latitude': 40.735279841425196,
#                        'longitude': -74.17179107666016}},
#  'total': 1200}

# %%
len(response['businesses'])
# Out:
# 20
