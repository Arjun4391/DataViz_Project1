# %% [markdown]
# # Name of the Project

# %% [markdown]
# ## Describe the core message or hypothesis for the project

# %% [markdown]
# ## Describe the questions you and your group found interesting, and what motivated you to answer them

# %% [markdown]
# ## Describe the data exploration and cleanup process

# %% [markdown]
# ### Read in Data Sources and cleanup the data

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from pprint import pprint

# %%
# Verify library versions if some error occurs

#pd.__version__ # Pandas version: 0.23.4
#np.__version__ # Numpy version: 1.15.4
#import matplotlib as mat
#mat.__version__ # Matplotlib version: 3.0.2

# %%
# Build URL
url = "https://chronicdata.cdc.gov/resource/mxg7-989n.json?"
topic = "topic=Obesity / Weight Status"
stratification_category = "stratificationcategoryid1=OVR"
question = "questionid=Q036"
query_url = f"{url}{topic}&{stratification_category}&{question}"

# %%
# Retrieve CDC obesity Data
responses = requests.get(query_url).json()

# Display the data
pprint(responses)
# Out:
# [{'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25.4',
#   'data_value_alt': '25.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-75.543970427, 42.827001032],
#                   'type': 'Point'},
#   'high_confidence_limit': '26.6',
#   'locationabbr': 'NY',
#   'locationdesc': 'New York',
#   'locationid': '36',
#   'low_confidence_limit': '24.2',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '8465',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2013',
#   'yearstart': '2013'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '28.9',
#   'data_value_alt': '28.9',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-68.985031336, 45.254228894001],
#                   'type': 'Point'},
#   'high_confidence_limit': '30.2',
#   'locationabbr': 'ME',
#   'locationdesc': 'Maine',
#   'locationid': '23',
#   'low_confidence_limit': '27.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7791',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2013',
#   'yearstart': '2013'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '30.7',
#   'data_value_alt': '30.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-89.816370742, 44.393191174],
#                   'type': 'Point'},
#   'high_confidence_limit': '32.5',
#   'locationabbr': 'WI',
#   'locationdesc': 'Wisconsin',
#   'locationid': '55',
#   'low_confidence_limit': '29',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4793',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '28.3',
#   'data_value_alt': '28.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-106.240580985, 34.520880952],
#                   'type': 'Point'},
#   'high_confidence_limit': '30.1',
#   'locationabbr': 'NM',
#   'locationdesc': 'New Mexico',
#   'locationid': '35',
#   'low_confidence_limit': '26.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '5531',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '26.6',
#   'data_value_alt': '26.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-71.50036092, 43.655950113], 'type': 'Point'},
#   'high_confidence_limit': '28.2',
#   'locationabbr': 'NH',
#   'locationdesc': 'New Hampshire',
#   'locationid': '33',
#   'low_confidence_limit': '25',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '5888',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '32.3',
#   'data_value_alt': '32.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-81.045371207, 33.998821303],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.6',
#   'locationabbr': 'SC',
#   'locationdesc': 'South Carolina',
#   'locationid': '45',
#   'low_confidence_limit': '31',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '10503',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25.5',
#   'data_value_alt': '25.5',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-109.424420645, 47.066528972],
#                   'type': 'Point'},
#   'high_confidence_limit': '27.2',
#   'locationabbr': 'MT',
#   'locationdesc': 'Montana',
#   'locationid': '30',
#   'low_confidence_limit': '23.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '5483',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31.2',
#   'data_value_alt': '31.2',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-98.200781227, 38.3477403], 'type': 'Point'},
#   'high_confidence_limit': '32.3',
#   'locationabbr': 'KS',
#   'locationdesc': 'Kansas',
#   'locationid': '20',
#   'low_confidence_limit': '30.1',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '10947',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '27.4',
#   'data_value_alt': '27.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-81.928960539, 28.932040377],
#                   'type': 'Point'},
#   'high_confidence_limit': '28.5',
#   'locationabbr': 'FL',
#   'locationdesc': 'Florida',
#   'locationid': '12',
#   'low_confidence_limit': '26.4',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '33186',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '30.7',
#   'data_value_alt': '30.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-75.577741168, 39.008830667],
#                   'type': 'Point'},
#   'high_confidence_limit': '32.8',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'locationid': '10',
#   'low_confidence_limit': '28.7',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '3702',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31',
#   'data_value_alt': '31',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-100.118421049, 47.475319779],
#                   'type': 'Point'},
#   'high_confidence_limit': '32.5',
#   'locationabbr': 'ND',
#   'locationdesc': 'North Dakota',
#   'locationid': '38',
#   'low_confidence_limit': '29.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7413',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2013',
#   'yearstart': '2013'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '30.3',
#   'data_value_alt': '30.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-77.860700294, 40.793730152],
#                   'type': 'Point'},
#   'high_confidence_limit': '31.8',
#   'locationabbr': 'PA',
#   'locationdesc': 'Pennsylvania',
#   'locationid': '42',
#   'low_confidence_limit': '28.8',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6367',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25',
#   'data_value_alt': '25',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-120.999999538, 37.638640123],
#                   'type': 'Point'},
#   'high_confidence_limit': '26.1',
#   'locationabbr': 'CA',
#   'locationdesc': 'California',
#   'locationid': '06',
#   'low_confidence_limit': '23.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '10352',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '23.8',
#   'data_value_alt': '23.8',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-157.857749403, 21.304850435],
#                   'type': 'Point'},
#   'high_confidence_limit': '25.2',
#   'locationabbr': 'HI',
#   'locationdesc': 'Hawaii',
#   'locationid': '15',
#   'low_confidence_limit': '22.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7659',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '24.3',
#   'data_value_alt': '24.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-72.082690675, 42.27687047], 'type': 'Point'},
#   'high_confidence_limit': '25.6',
#   'locationabbr': 'MA',
#   'locationdesc': 'Massachusetts',
#   'locationid': '25',
#   'low_confidence_limit': '23',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '8206',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2015',
#   'yearstart': '2015'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '32.5',
#   'data_value_alt': '32.5',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-86.149960194, 39.766910452],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.8',
#   'locationabbr': 'IN',
#   'locationdesc': 'Indiana',
#   'locationid': '18',
#   'low_confidence_limit': '31.2',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '10319',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '27.4',
#   'data_value_alt': '27.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-114.363730042, 43.682630005],
#                   'type': 'Point'},
#   'high_confidence_limit': '29.3',
#   'locationabbr': 'ID',
#   'locationdesc': 'Idaho',
#   'locationid': '16',
#   'low_confidence_limit': '25.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4880',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '29.9',
#   'data_value_alt': '29.9',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-76.609260111, 39.290580964],
#                   'type': 'Point'},
#   'high_confidence_limit': '31',
#   'locationabbr': 'MD',
#   'locationdesc': 'Maryland',
#   'locationid': '24',
#   'low_confidence_limit': '28.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '16701',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31.6',
#   'data_value_alt': '31.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-88.997710178, 40.485010283],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.3',
#   'locationabbr': 'IL',
#   'locationdesc': 'Illinois',
#   'locationid': '17',
#   'low_confidence_limit': '29.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4518',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '26.6',
#   'data_value_alt': '26.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-71.522470314, 41.708280193],
#                   'type': 'Point'},
#   'high_confidence_limit': '28.4',
#   'locationabbr': 'RI',
#   'locationdesc': 'Rhode Island',
#   'locationid': '44',
#   'low_confidence_limit': '24.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4936',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '33.7',
#   'data_value_alt': '33.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-99.426770206, 31.827240407],
#                   'type': 'Point'},
#   'high_confidence_limit': '35.4',
#   'locationabbr': 'TX',
#   'locationdesc': 'Texas',
#   'locationid': '48',
#   'low_confidence_limit': '31.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '10789',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '23.6',
#   'data_value_alt': '23.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-72.082690675, 42.27687047], 'type': 'Point'},
#   'high_confidence_limit': '24.9',
#   'locationabbr': 'MA',
#   'locationdesc': 'Massachusetts',
#   'locationid': '25',
#   'low_confidence_limit': '22.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7480',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '26',
#   'data_value_alt': '26',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-72.649840952, 41.56266102], 'type': 'Point'},
#   'high_confidence_limit': '27.2',
#   'locationabbr': 'CT',
#   'locationdesc': 'Connecticut',
#   'locationid': '09',
#   'low_confidence_limit': '24.8',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '9960',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '27.4',
#   'data_value_alt': '27.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-74.273691288, 40.130570048],
#                   'type': 'Point'},
#   'high_confidence_limit': '29.1',
#   'locationabbr': 'NJ',
#   'locationdesc': 'New Jersey',
#   'locationid': '34',
#   'low_confidence_limit': '25.7',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6810',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25.5',
#   'data_value_alt': '25.5',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-75.543970427, 42.827001032],
#                   'type': 'Point'},
#   'high_confidence_limit': '26.5',
#   'locationabbr': 'NY',
#   'locationdesc': 'New York',
#   'locationid': '36',
#   'low_confidence_limit': '24.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '31269',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '32.2',
#   'data_value_alt': '32.2',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-100.118421049, 47.475319779],
#                   'type': 'Point'},
#   'high_confidence_limit': '34',
#   'locationabbr': 'ND',
#   'locationdesc': 'North Dakota',
#   'locationid': '38',
#   'low_confidence_limit': '30.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7269',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2014',
#   'yearstart': '2014'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '34.8',
#   'data_value_alt': '34.8',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-85.774490914, 35.68094058], 'type': 'Point'},
#   'high_confidence_limit': '36.7',
#   'locationabbr': 'TN',
#   'locationdesc': 'Tennessee',
#   'locationid': '47',
#   'low_confidence_limit': '33',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '5657',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '27.1',
#   'data_value_alt': '27.1',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-72.517640791, 43.625381239],
#                   'type': 'Point'},
#   'high_confidence_limit': '28.7',
#   'locationabbr': 'VT',
#   'locationdesc': 'Vermont',
#   'locationid': '50',
#   'low_confidence_limit': '25.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6071',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '34.6',
#   'data_value_alt': '34.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-89.538030825, 32.745510099],
#                   'type': 'Point'},
#   'high_confidence_limit': '36.2',
#   'locationabbr': 'MS',
#   'locationdesc': 'Mississippi',
#   'locationid': '28',
#   'low_confidence_limit': '33.1',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7429',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '32',
#   'data_value_alt': '32',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-86.631860762, 32.840571122],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.5',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'locationid': '01',
#   'low_confidence_limit': '30.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7304',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2011',
#   'yearstart': '2011'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '28.6',
#   'data_value_alt': '28.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-120.47001079, 47.522278629],
#                   'type': 'Point'},
#   'high_confidence_limit': '29.6',
#   'locationabbr': 'WA',
#   'locationdesc': 'Washington',
#   'locationid': '53',
#   'low_confidence_limit': '27.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '12990',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25.4',
#   'data_value_alt': '25.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-111.587130635, 39.360700171],
#                   'type': 'Point'},
#   'high_confidence_limit': '26.5',
#   'locationabbr': 'UT',
#   'locationdesc': 'Utah',
#   'locationid': '49',
#   'low_confidence_limit': '24.2',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '10043',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31.5',
#   'data_value_alt': '31.5',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-82.404260056, 40.060210141],
#                   'type': 'Point'},
#   'high_confidence_limit': '32.8',
#   'locationabbr': 'OH',
#   'locationdesc': 'Ohio',
#   'locationid': '39',
#   'low_confidence_limit': '30.2',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '11455',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '29',
#   'data_value_alt': '29',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-78.457890463, 37.542680674],
#                   'type': 'Point'},
#   'high_confidence_limit': '30.3',
#   'locationabbr': 'VA',
#   'locationdesc': 'Virginia',
#   'locationid': '51',
#   'low_confidence_limit': '27.7',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '8293',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '34.2',
#   'data_value_alt': '34.2',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-84.774971048, 37.645970271],
#                   'type': 'Point'},
#   'high_confidence_limit': '35.6',
#   'locationabbr': 'KY',
#   'locationdesc': 'Kentucky',
#   'locationid': '21',
#   'low_confidence_limit': '32.7',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '9583',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25.8',
#   'data_value_alt': '25.8',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-117.071840564, 39.49324039],
#                   'type': 'Point'},
#   'high_confidence_limit': '27.8',
#   'locationabbr': 'NV',
#   'locationdesc': 'Nevada',
#   'locationid': '32',
#   'low_confidence_limit': '23.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '3981',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '29.6',
#   'data_value_alt': '29.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'high_confidence_limit': '29.8',
#   'locationabbr': 'US',
#   'locationdesc': 'National',
#   'locationid': '59',
#   'low_confidence_limit': '29.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '438479',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '37.3',
#   'data_value_alt': '37.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-89.538030825, 32.745510099],
#                   'type': 'Point'},
#   'high_confidence_limit': '39.1',
#   'locationabbr': 'MS',
#   'locationdesc': 'Mississippi',
#   'locationid': '28',
#   'low_confidence_limit': '35.4',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4821',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '32',
#   'data_value_alt': '32',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-93.816490556, 42.469400913],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.4',
#   'locationabbr': 'IA',
#   'locationdesc': 'Iowa',
#   'locationid': '19',
#   'low_confidence_limit': '30.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6645',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31.4',
#   'data_value_alt': '31.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-83.627580346, 32.839681093],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.2',
#   'locationabbr': 'GA',
#   'locationdesc': 'Georgia',
#   'locationid': '13',
#   'low_confidence_limit': '29.7',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4884',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '22.3',
#   'data_value_alt': '22.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-106.133610921, 38.843840757],
#                   'type': 'Point'},
#   'high_confidence_limit': '23.2',
#   'locationabbr': 'CO',
#   'locationdesc': 'Colorado',
#   'locationid': '08',
#   'low_confidence_limit': '21.4',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '13637',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '24.6',
#   'data_value_alt': '24.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-74.273691288, 40.130570048],
#                   'type': 'Point'},
#   'high_confidence_limit': '25.6',
#   'locationabbr': 'NJ',
#   'locationdesc': 'New Jersey',
#   'locationid': '34',
#   'low_confidence_limit': '23.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '14477',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '35.5',
#   'data_value_alt': '35.5',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-92.445680071, 31.312660644],
#                   'type': 'Point'},
#   'high_confidence_limit': '37.7',
#   'locationabbr': 'LA',
#   'locationdesc': 'Louisiana',
#   'locationid': '22',
#   'low_confidence_limit': '33.4',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4868',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '28.3',
#   'data_value_alt': '28.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [144.793731, 13.444304], 'type': 'Point'},
#   'high_confidence_limit': '31.7',
#   'locationabbr': 'GU',
#   'locationdesc': 'Guam',
#   'locationid': '66',
#   'low_confidence_limit': '25.1',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '1477',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '32',
#   'data_value_alt': '32',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-99.365720623, 41.641040988001],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.2',
#   'locationabbr': 'NE',
#   'locationdesc': 'Nebraska',
#   'locationid': '31',
#   'low_confidence_limit': '30.8',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '14173',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '26.8',
#   'data_value_alt': '26.8',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-120.47001079, 47.522278629],
#                   'type': 'Point'},
#   'high_confidence_limit': '27.8',
#   'locationabbr': 'WA',
#   'locationdesc': 'Washington',
#   'locationid': '53',
#   'low_confidence_limit': '25.8',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '14540',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '28.3',
#   'data_value_alt': '28.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-76.609260111, 39.290580964],
#                   'type': 'Point'},
#   'high_confidence_limit': '29.7',
#   'locationabbr': 'MD',
#   'locationdesc': 'Maryland',
#   'locationid': '24',
#   'low_confidence_limit': '26.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '9450',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2011',
#   'yearstart': '2011'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '27.7',
#   'data_value_alt': '27.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-108.109830353, 43.235541343],
#                   'type': 'Point'},
#   'high_confidence_limit': '29.8',
#   'locationabbr': 'WY',
#   'locationdesc': 'Wyoming',
#   'locationid': '56',
#   'low_confidence_limit': '25.7',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4200',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '35.7',
#   'data_value_alt': '35.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-86.631860762, 32.840571122],
#                   'type': 'Point'},
#   'high_confidence_limit': '37.3',
#   'locationabbr': 'AL',
#   'locationdesc': 'Alabama',
#   'locationid': '01',
#   'low_confidence_limit': '34.2',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6526',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '28.7',
#   'data_value_alt': '28.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-120.155031326, 44.567449424],
#                   'type': 'Point'},
#   'high_confidence_limit': '30.3',
#   'locationabbr': 'OR',
#   'locationdesc': 'Oregon',
#   'locationid': '41',
#   'low_confidence_limit': '27.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '5000',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '29.6',
#   'data_value_alt': '29.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-100.373530637, 44.353130053],
#                   'type': 'Point'},
#   'high_confidence_limit': '31.7',
#   'locationabbr': 'SD',
#   'locationdesc': 'South Dakota',
#   'locationid': '46',
#   'low_confidence_limit': '27.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '5371',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '35.7',
#   'data_value_alt': '35.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-92.274490743, 34.748650124],
#                   'type': 'Point'},
#   'high_confidence_limit': '38.1',
#   'locationabbr': 'AR',
#   'locationdesc': 'Arkansas',
#   'locationid': '05',
#   'low_confidence_limit': '33.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4859',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '29.6',
#   'data_value_alt': '29.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-92.566300053, 38.635790776],
#                   'type': 'Point'},
#   'high_confidence_limit': '31.2',
#   'locationabbr': 'MO',
#   'locationdesc': 'Missouri',
#   'locationid': '29',
#   'low_confidence_limit': '28',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6446',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31.7',
#   'data_value_alt': '31.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-92.566300053, 38.635790776],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.4',
#   'locationabbr': 'MO',
#   'locationdesc': 'Missouri',
#   'locationid': '29',
#   'low_confidence_limit': '30',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6578',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '22.6',
#   'data_value_alt': '22.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-77.031961127, 38.890371385],
#                   'type': 'Point'},
#   'high_confidence_limit': '24.3',
#   'locationabbr': 'DC',
#   'locationdesc': 'District of Columbia',
#   'locationid': '11',
#   'low_confidence_limit': '20.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '3479',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2016',
#   'yearstart': '2016'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '26.9',
#   'data_value_alt': '26.9',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-75.577741168, 39.008830667],
#                   'type': 'Point'},
#   'high_confidence_limit': '28.6',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'locationid': '10',
#   'low_confidence_limit': '25.2',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
# ...
#   'locationdesc': 'North Dakota',
#   'locationid': '38',
#   'low_confidence_limit': '29.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4612',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2015',
#   'yearstart': '2015'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '30.5',
#   'data_value_alt': '30.5',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-83.627580346, 32.839681093],
#                   'type': 'Point'},
#   'high_confidence_limit': '32.1',
#   'locationabbr': 'GA',
#   'locationdesc': 'Georgia',
#   'locationid': '13',
#   'low_confidence_limit': '28.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '5844',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2014',
#   'yearstart': '2014'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '29.7',
#   'data_value_alt': '29.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-75.577741168, 39.008830667],
#                   'type': 'Point'},
#   'high_confidence_limit': '31.8',
#   'locationabbr': 'DE',
#   'locationdesc': 'Delaware',
#   'locationid': '10',
#   'low_confidence_limit': '27.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '3688',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2015',
#   'yearstart': '2015'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '27.6',
#   'data_value_alt': '27.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-76.609260111, 39.290580964],
#                   'type': 'Point'},
#   'high_confidence_limit': '28.9',
#   'locationabbr': 'MD',
#   'locationdesc': 'Maryland',
#   'locationid': '24',
#   'low_confidence_limit': '26.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '11947',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '22.1',
#   'data_value_alt': '22.1',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-157.857749403, 21.304850435],
#                   'type': 'Point'},
#   'high_confidence_limit': '23.5',
#   'locationabbr': 'HI',
#   'locationdesc': 'Hawaii',
#   'locationid': '15',
#   'low_confidence_limit': '20.7',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6905',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2014',
#   'yearstart': '2014'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25.6',
#   'data_value_alt': '25.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-72.649840952, 41.56266102], 'type': 'Point'},
#   'high_confidence_limit': '26.9',
#   'locationabbr': 'CT',
#   'locationdesc': 'Connecticut',
#   'locationid': '09',
#   'low_confidence_limit': '24.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '8312',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '24.4',
#   'data_value_alt': '24.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-111.587130635, 39.360700171],
#                   'type': 'Point'},
#   'high_confidence_limit': '25.5',
#   'locationabbr': 'UT',
#   'locationdesc': 'Utah',
#   'locationid': '49',
#   'low_confidence_limit': '23.4',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '11918',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2011',
#   'yearstart': '2011'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '24.5',
#   'data_value_alt': '24.5',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-72.649840952, 41.56266102], 'type': 'Point'},
#   'high_confidence_limit': '26',
#   'locationabbr': 'CT',
#   'locationdesc': 'Connecticut',
#   'locationid': '09',
#   'low_confidence_limit': '23',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6457',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2011',
#   'yearstart': '2011'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '25',
#   'data_value_alt': '25',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-72.649840952, 41.56266102], 'type': 'Point'},
#   'high_confidence_limit': '26.4',
#   'locationabbr': 'CT',
#   'locationdesc': 'Connecticut',
#   'locationid': '09',
#   'low_confidence_limit': '23.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '7309',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2013',
#   'yearstart': '2013'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '29.6',
#   'data_value_alt': '29.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-79.159250463, 35.466220975],
#                   'type': 'Point'},
#   'high_confidence_limit': '30.7',
#   'locationabbr': 'NC',
#   'locationdesc': 'North Carolina',
#   'locationid': '37',
#   'low_confidence_limit': '28.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '11113',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '34.6',
#   'data_value_alt': '34.6',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-84.774971048, 37.645970271],
#                   'type': 'Point'},
#   'high_confidence_limit': '36.3',
#   'locationabbr': 'KY',
#   'locationdesc': 'Kentucky',
#   'locationid': '21',
#   'low_confidence_limit': '32.9',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '8130',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2015',
#   'yearstart': '2015'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '26.2',
#   'data_value_alt': '26.2',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-81.928960539, 28.932040377],
#                   'type': 'Point'},
#   'high_confidence_limit': '27.5',
#   'locationabbr': 'FL',
#   'locationdesc': 'Florida',
#   'locationid': '12',
#   'low_confidence_limit': '25',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '9156',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2014',
#   'yearstart': '2014'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '34.7',
#   'data_value_alt': '34.7',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-92.445680071, 31.312660644],
#                   'type': 'Point'},
#   'high_confidence_limit': '36.4',
#   'locationabbr': 'LA',
#   'locationdesc': 'Louisiana',
#   'locationid': '22',
#   'low_confidence_limit': '33.1',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '8656',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2012',
#   'yearstart': '2012'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '30.4',
#   'data_value_alt': '30.4',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-92.566300053, 38.635790776],
#                   'type': 'Point'},
#   'high_confidence_limit': '32.1',
#   'locationabbr': 'MO',
#   'locationdesc': 'Missouri',
#   'locationid': '29',
#   'low_confidence_limit': '28.8',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6783',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2013',
#   'yearstart': '2013'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '28.9',
#   'data_value_alt': '28.9',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-76.609260111, 39.290580964],
#                   'type': 'Point'},
#   'high_confidence_limit': '30.7',
#   'locationabbr': 'MD',
#   'locationdesc': 'Maryland',
#   'locationid': '24',
#   'low_confidence_limit': '27.2',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '11357',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2015',
#   'yearstart': '2015'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31.2',
#   'data_value_alt': '31.2',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-85.774490914, 35.68094058], 'type': 'Point'},
#   'high_confidence_limit': '33.2',
#   'locationabbr': 'TN',
#   'locationdesc': 'Tennessee',
#   'locationid': '47',
#   'low_confidence_limit': '29.3',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '4793',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2014',
#   'yearstart': '2014'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '30.3',
#   'data_value_alt': '30.3',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-92.566300053, 38.635790776],
#                   'type': 'Point'},
#   'high_confidence_limit': '32',
#   'locationabbr': 'MO',
#   'locationdesc': 'Missouri',
#   'locationid': '29',
#   'low_confidence_limit': '28.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '6095',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2011',
#   'yearstart': '2011'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '31.8',
#   'data_value_alt': '31.8',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-86.149960194, 39.766910452],
#                   'type': 'Point'},
#   'high_confidence_limit': '33.1',
#   'locationabbr': 'IN',
#   'locationdesc': 'Indiana',
#   'locationid': '18',
#   'low_confidence_limit': '30.6',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '9770',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2013',
#   'yearstart': '2013'},
#  {'class': 'Obesity / Weight Status',
#   'classid': 'OWS',
#   'data_value': '30.9',
#   'data_value_alt': '30.9',
#   'data_value_type': 'Value',
#   'datasource': 'Behavioral Risk Factor Surveillance System',
#   'datavaluetypeid': 'VALUE',
#   'geolocation': {'coordinates': [-99.426770206, 31.827240407],
#                   'type': 'Point'},
#   'high_confidence_limit': '32.3',
#   'locationabbr': 'TX',
#   'locationdesc': 'Texas',
#   'locationid': '48',
#   'low_confidence_limit': '29.5',
#   'question': 'Percent of adults aged 18 years and older who have obesity',
#   'questionid': 'Q036',
#   'sample_size': '10085',
#   'stratification1': 'Total',
#   'stratificationcategory1': 'Total',
#   'stratificationcategoryid1': 'OVR',
#   'stratificationid1': 'OVERALL',
#   'topic': 'Obesity / Weight Status',
#   'topicid': 'OWS1',
#   'total': 'Total',
#   'yearend': '2013',
#   'yearstart': '2013'}]

# %%
# Create lists to store CDC information

year_ovr = []
location_ovr = []
value_ovr = []

# Loop through items
for response in responses:
    try:
        year = response['yearstart']
        location = response['locationabbr']
        value = response['data_value']
    
        year_ovr.append(year)
        location_ovr.append(location)
        value_ovr.append(value)
    except KeyError:
        next

data_ovr = pd.DataFrame({'Year': year_ovr,
                         'Location': location_ovr,
                         'Obesity Percentage': value_ovr
                        })
data_ovr.head()
# Out:
#    Year Location Obesity Percentage
# 0  2013       NY               25.4
# 1  2013       ME               28.9
# 2  2016       WI               30.7
# 3  2016       NM               28.3
# 4  2016       NH               26.6

# %%
# Get data information
data_ovr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 3 columns):
# Year                  374 non-null object
# Location              374 non-null object
# Obesity Percentage    374 non-null object
# dtypes: object(3)
# memory usage: 8.8+ KB

# %%
# Change Obesity Percentage data type to float
data_ovr["Obesity Percentage"] = data_ovr["Obesity Percentage"].astype(float)

# Change Year data type to 
data_ovr["Year"] = data_ovr["Year"].astype(int)

# %%
# Create dataframe just for States
df_states = data_ovr[data_ovr['Location'] != 'US']
df_states = df_states.reset_index(drop = True)

# Create dataframe for US
df_us = data_ovr[data_ovr['Location'] == 'US']
df_us = df_us.sort_values(by = 'Year')
df_us = df_us.reset_index(drop = True)

# %%
# Display States dataframe
df_states.head()
# Out:
#    Year Location  Obesity Percentage
# 0  2013       NY                25.4
# 1  2013       ME                28.9
# 2  2016       WI                30.7
# 3  2016       NM                28.3
# 4  2016       NH                26.6

# %%
# Display US dataframe
df_us
# Out:
#    Year Location  Obesity Percentage
# 0  2011       US                27.4
# 1  2012       US                27.7
# 2  2013       US                28.3
# 3  2014       US                28.9
# 4  2015       US                28.9
# 5  2016       US                29.6
# 6  2017       US                30.1

# %%
# Filter 2017 data for states
df_states_2017 = df_states[df_states["Year"] == 2017]

# Sort 2017 data to discover top Obsesity Percentage
df_states_2017 = df_states_2017.sort_values(by = 'Obesity Percentage', ascending = False)
df_states_2017 = df_states_2017.reset_index(drop = True)

# %%
# Display Top 5 States
df_states_2017.head()
# Out:
#    Year Location  Obesity Percentage
# 0  2017       WV                38.1
# 1  2017       MS                37.3
# 2  2017       OK                36.5
# 3  2017       IA                36.4
# 4  2017       AL                36.3

# %%
# Display Bottom 5 States
df_states_2017.tail()
# Out:
#     Year Location  Obesity Percentage
# 48  2017       UT                25.3
# 49  2017       CA                25.1
# 50  2017       HI                23.8
# 51  2017       DC                23.0
# 52  2017       CO                22.6

# %% [markdown]
# ## Describe the analysis process

# %% [markdown]
# ### Plot US obesity data: overal, by gender, by age, etc...

# %%
# Plot data for US
plt.plot(df_us["Year"], df_us["Obesity Percentage"], marker = ">")

plt.title("US Obesity Percentages from 2011 to 2017", size = 13, weight = 'bold')
plt.xlabel("Years", labelpad=20, size = 12,  weight = 'bold')
plt.ylabel("Obesity Percentages", labelpad=20, size = 12, weight = 'bold')

plt.show()

# %% [markdown]
# ### Plot obesity states rank: first 5 and last 5

# %%
df_top5_states = df_states_2017.head().groupby('Location').sum()
df_top5_states = df_top5_states['Obesity Percentage'].sort_values()

fig, ax = plt.subplots(1,2)

ax[0] = df_top5_states.plot(kind='barh', figsize=(6, 5), color='#86bf91', zorder=2, width=0.85)

# Despine
ax[0].spines['right'].set_visible(False)
ax[0].spines['top'].set_visible(False)
ax[0].spines['left'].set_visible(False)
ax[0].spines['bottom'].set_visible(False)

# Switch off ticks
ax[0].tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax[0].get_xticks()
for tick in vals:
    ax[0].axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax[0].set_xlabel("Obesity Percentages", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax[0].set_ylabel("States", labelpad=20, weight='bold', size=12)

# Set Title
ax[0].set_title('Top 5 Obese States', weight = 'bold', size = 15, loc = 'center')

[ax[0].text(v, i, '{:.2f}%'.format(v)) for i, v in enumerate(df_top5_states)]
        
plt.show()
# Out:
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %% [markdown]
# ### Analyze restaurants (health and unhealth) yelp data for the 5 first and last states

# %%
df_top5_states = df_states_2017.head().groupby('Location').sum()
df_top5_states = df_top5_states['Obesity Percentage'].sort_values()

fig, (ax1,ax2) = plt.subplots(1,2)

ax = df_top5_states.plot(kind='bar')
#ax2 = df_top5_states.plot(kind='bar', figsize=(6, 5), color='#86bf91', zorder=2, width=0.85)
